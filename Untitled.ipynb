# %%
import tweepy

# %%
import App
# Out:
# G:\Apps\Conda\envs\tensorflow\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# -------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-2-558af4219529> in <module>()
# ----> 1 import App
#
# G:\Programming\major\App.py in <module>()
#       5 import pickle
#       6 from os import listdir, path
# ----> 7 from models.User import User, UserType
#       8 from models.Tweet import Tweet
#       9 # from utils.logging import LogMixin
#
# G:\Programming\major\models\User.py in <module>()
#       1 """User module containing User Model and UserType Enum """
#       2 from enum import Enum
# ----> 3 from models.Tweet import Tweet
#       4
#       5
#
# G:\Programming\major\models\Tweet.py in <module>()
#       4 """
#       5 import params
# ----> 6 from vectorize.vectorize import model
# ...

# %%
import App

# %%
import App

# %%
with open(os.path.join(os.path.dirname(__file__), 'data\\users.dat'), mode='rb') as file:
    UM = pickle.load(file)
# Out:
# -------------------------------------------------
# NameError       Traceback (most recent call last)
# <ipython-input-5-2cc7de938a35> in <module>()
# ----> 1 with open(os.path.join(os.path.dirname(__file__), 'data\\users.dat'), mode='rb') as file:
#       2     UM = pickle.load(file)
#
# NameError: name 'os' is not defined

# %%
import os

# %%
import pickle

# %%
with open(os.path.join(os.path.dirname(__file__), 'data\\users.dat'), mode='rb') as file:
    UM = pickle.load(file)
# Out:
# -------------------------------------------------
# NameError       Traceback (most recent call last)
# <ipython-input-8-2cc7de938a35> in <module>()
# ----> 1 with open(os.path.join(os.path.dirname(__file__), 'data\\users.dat'), mode='rb') as file:
#       2     UM = pickle.load(file)
#
# NameError: name '__file__' is not defined

# %%
with open('G:\\Programming\\major\\data\\users.dat', mode='rb') as file:
    UM = pickle.load(file)

# %%
UM = UserMaker()
# Out:
# -------------------------------------------------
# NameError       Traceback (most recent call last)
# <ipython-input-10-c2270973e933> in <module>()
# ----> 1 UM = UserMaker()
#
# NameError: name 'UserMaker' is not defined

# %%
UM = App.UserMaker()

# %%
UserMaker = App.UserMaker

# %%
UM.users
# Out:
# ...
#  ...]

# %%
from nltk.tokenize import TweetTokenizer

# %%
tweet = UM.users[0].tweets[0]

# %%
tweet

# %%
tweet.text
# Out:
# 'Top Beaches of Australia https://t.co/UWobwvRFA3 #topbeaches #beach #australia https://t.co/xDFNmASQfJ'

# %%
tokenizer = TweetTokenizer()

# %%
tokenizer.tokenize(tweet.text)
# Out:
# ['Top',
#  'Beaches',
#  'of',
#  'Australia',
#  'https://t.co/UWobwvRFA3',
#  '#topbeaches',
#  '#beach',
#  '#australia',
#  'https://t.co/xDFNmASQfJ']

# %%
tweetList = []
for user in UM.users:
    tweetList += user.tweets

# %%
tweet_dict = {tweet.text : len(tokenizer.tokenize(tweet.text)) for tweet in tweetList}

# %%
max(tweet_dict, key = lambda x : tweet_dict[x])
# Out:
# '#الناس_بهذا_الوقت ♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️'

# %%
arabic_text = '#الناس_بهذا_الوقت ♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️♣️♥️'

# %%
import re
test = re.compile(r'[\u0600-\u06FF]', re.UNICODE)
y = test.search(arabic_text)

# %%
y
# Out:
# <_sre.SRE_Match object; span=(1, 2), match='ا'>

# %%
print(y)
# Out:
# <_sre.SRE_Match object; span=(1, 2), match='ا'>
